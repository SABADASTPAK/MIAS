# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

def parse_info_txt(file_path, start_line=1):
    """Parse MIAS Info.txt file and return a clean DataFrame."""
    data = []

    with open(file_path, 'r') as f:
        lines = f.readlines()[start_line - 1:]

        for line in lines:
            parts = line.strip().split()

            # Skip invalid lines
            if not parts or not parts[0].startswith("mdb"):
                continue

            try:
                # Parse common fields
                entry = {
                    "ID": parts[0],
                    "Breast Density": parts[1],
                    "Abnormality Type": parts[2] if len(parts) > 2 else "",
                    "Severity": parts[3] if len(parts) > 3 else "",
                    "X": float(parts[4]) if len(parts) > 4 else None,
                    "Y": float(parts[5]) if len(parts) > 5 else None,
                    "Radius": float(parts[6]) if len(parts) > 6 else None,
                }
                data.append(entry)
            except Exception as e:
                print(f"Skipping malformed line: {line.strip()} -> {e}")

    return pd.DataFrame(data)

# %%
info_file = "/content/drive/MyDrive/miniMIAS_Dataset/Info.txt"  # Change path if needed

df_info = parse_info_txt(info_file)
df_info.head()
# Out:
# Skipping malformed line: mdb216 D CALC M *NOTE 3* -> could not convert string to float: '*NOTE'
# Skipping malformed line: mdb233 G CALC M *NOTE 3* -> could not convert string to float: '*NOTE'
# Skipping malformed line: mdb245 F CALC M *NOTE 3* -> could not convert string to float: '*NOTE'
#        ID Breast Density Abnormality Type Severity      X      Y  Radius
# 0  mdb001              G             CIRC        B  535.0  425.0   197.0
# 1  mdb002              G             CIRC        B  522.0  280.0    69.0
# 2  mdb003              D             NORM             NaN    NaN     NaN
# 3  mdb004              D             NORM             NaN    NaN     NaN
# 4  mdb005              F             CIRC        B  477.0  133.0    30.0

# %%
df_info.to_csv("mias_parsed_info.csv", index=False)

# %%
# Filter rows where Abnormality Type is 'CIRC'
df_circ = df_info[df_info["Abnormality Type"] == "CIRC"]

# Print all matching rows
print(df_circ.to_string(index=False))
# Out:
#     ID Breast Density Abnormality Type Severity     X     Y  Radius
# mdb001              G             CIRC        B 535.0 425.0   197.0
# mdb002              G             CIRC        B 522.0 280.0    69.0
# mdb005              F             CIRC        B 477.0 133.0    30.0
# mdb005              F             CIRC        B 500.0 168.0    26.0
# mdb010              F             CIRC        B 525.0 425.0    33.0
# mdb012              F             CIRC        B 471.0 458.0    40.0
# mdb015              G             CIRC        B 595.0 864.0    68.0
# mdb017              G             CIRC        B 547.0 573.0    48.0
# mdb019              G             CIRC        B 653.0 477.0    49.0
# mdb021              G             CIRC        B 493.0 125.0    49.0
# mdb023              G             CIRC        M 538.0 681.0    29.0
# mdb025              F             CIRC        B 674.0 443.0    79.0
# mdb028              F             CIRC        M 338.0 314.0    56.0
# mdb059              F             CIRC        B   NaN   NaN     NaN
# mdb069              F             CIRC        B 462.0 406.0    44.0
# mdb080              F             CIRC        B 432.0 149.0    20.0
# mdb091              F             CIRC        B 680.0 494.0    20.0
# mdb132              F             CIRC        B 252.0 788.0    52.0
# mdb132              F             CIRC        B 335.0 766.0    18.0
# mdb141              F             CIRC        M 470.0 759.0    29.0
# mdb142              F             CIRC        B 347.0 636.0    26.0
# mdb244              D             CIRC        B 466.0 567.0    52.0
# mdb270              G             CIRC        M 356.0 945.0    72.0
# mdb290              D             CIRC        B 337.0 353.0    45.0
# mdb315              D             CIRC        B 516.0 447.0    93.0

# %%
df_info_filtered = df_info[~(
    df_info["Severity"].isin(["B", "M"]) &
    (df_info["X"].isna() | df_info["Y"].isna() | df_info["Radius"].isna())
)]

# %%
# Display all rows (avoid truncation)
pd.set_option('display.max_rows', None)

# Show the DataFrame
print(df_info_filtered)
# Out:
#          ID Breast Density Abnormality Type Severity      X      Y  Radius
# 0    mdb001              G             CIRC        B  535.0  425.0   197.0
# 1    mdb002              G             CIRC        B  522.0  280.0    69.0
# 2    mdb003              D             NORM             NaN    NaN     NaN
# 3    mdb004              D             NORM             NaN    NaN     NaN
# 4    mdb005              F             CIRC        B  477.0  133.0    30.0
# 5    mdb005              F             CIRC        B  500.0  168.0    26.0
# 6    mdb006              F             NORM             NaN    NaN     NaN
# 7    mdb007              G             NORM             NaN    NaN     NaN
# 8    mdb008              G             NORM             NaN    NaN     NaN
# 9    mdb009              F             NORM             NaN    NaN     NaN
# 10   mdb010              F             CIRC        B  525.0  425.0    33.0
# 11   mdb011              F             NORM             NaN    NaN     NaN
# 12   mdb012              F             CIRC        B  471.0  458.0    40.0
# 13   mdb013              G             MISC        B  667.0  365.0    31.0
# 14   mdb014              G             NORM             NaN    NaN     NaN
# 15   mdb015              G             CIRC        B  595.0  864.0    68.0
# 16   mdb016              G             NORM             NaN    NaN     NaN
# 17   mdb017              G             CIRC        B  547.0  573.0    48.0
# 18   mdb018              G             NORM             NaN    NaN     NaN
# 19   mdb019              G             CIRC        B  653.0  477.0    49.0
# 20   mdb020              G             NORM             NaN    NaN     NaN
# 21   mdb021              G             CIRC        B  493.0  125.0    49.0
# 22   mdb022              G             NORM             NaN    NaN     NaN
# 23   mdb023              G             CIRC        M  538.0  681.0    29.0
# 24   mdb024              G             NORM             NaN    NaN     NaN
# 25   mdb025              F             CIRC        B  674.0  443.0    79.0
# 26   mdb026              F             NORM             NaN    NaN     NaN
# 27   mdb027              F             NORM             NaN    NaN     NaN
# 28   mdb028              F             CIRC        M  338.0  314.0    56.0
# 29   mdb029              G             NORM             NaN    NaN     NaN
# 30   mdb030              G             MISC        B  322.0  676.0    43.0
# 31   mdb031              G             NORM             NaN    NaN     NaN
# 32   mdb032              G             MISC        B  388.0  742.0    66.0
# 33   mdb033              D             NORM             NaN    NaN     NaN
# 34   mdb034              D             NORM             NaN    NaN     NaN
# 35   mdb035              D             NORM             NaN    NaN     NaN
# 36   mdb036              D             NORM             NaN    NaN     NaN
# 37   mdb037              D             NORM             NaN    NaN     NaN
# 38   mdb038              D             NORM             NaN    NaN     NaN
# 39   mdb039              D             NORM             NaN    NaN     NaN
# 40   mdb040              D             NORM             NaN    NaN     NaN
# 41   mdb041              G             NORM             NaN    NaN     NaN
# 42   mdb042              G             NORM             NaN    NaN     NaN
# 43   mdb043              G             NORM             NaN    NaN     NaN
# 44   mdb044              G             NORM             NaN    NaN     NaN
# 45   mdb045              G             NORM             NaN    NaN     NaN
# 46   mdb046              G             NORM             NaN    NaN     NaN
# 47   mdb047              G             NORM             NaN    NaN     NaN
# 48   mdb048              G             NORM             NaN    NaN     NaN
# 49   mdb049              G             NORM             NaN    NaN     NaN
# 50   mdb050              G             NORM             NaN    NaN     NaN
# 51   mdb051              G             NORM             NaN    NaN     NaN
# 52   mdb052              G             NORM             NaN    NaN     NaN
# 53   mdb053              D             NORM             NaN    NaN     NaN
# 54   mdb054              D             NORM             NaN    NaN     NaN
# 55   mdb055              G             NORM             NaN    NaN     NaN
# 56   mdb056              G             NORM             NaN    NaN     NaN
# 57   mdb057              D             NORM             NaN    NaN     NaN
# 58   mdb058              D             MISC        M  318.0  359.0    27.0
# 60   mdb060              F             NORM             NaN    NaN     NaN
# 61   mdb061              D             NORM             NaN    NaN     NaN
# 62   mdb062              D             NORM             NaN    NaN     NaN
# 63   mdb063              D             MISC        B  546.0  463.0    33.0
# 64   mdb064              D             NORM             NaN    NaN     NaN
# 65   mdb065              D             NORM             NaN    NaN     NaN
# 66   mdb066              D             NORM             NaN    NaN     NaN
# 67   mdb067              D             NORM             NaN    NaN     NaN
# 68   mdb068              D             NORM             NaN    NaN     NaN
# 69   mdb069              F             CIRC        B  462.0  406.0    44.0
# 70   mdb070              F             NORM             NaN    NaN     NaN
# 71   mdb071              G             NORM             NaN    NaN     NaN
# 72   mdb072              G             ASYM        M  266.0  517.0    28.0
# 73   mdb073              G             NORM             NaN    NaN     NaN
# 74   mdb074              G             NORM             NaN    NaN     NaN
# 75   mdb075              F             ASYM        M  468.0  717.0    23.0
# 76   mdb076              F             NORM             NaN    NaN     NaN
# 77   mdb077              F             NORM             NaN    NaN     NaN
# 78   mdb078              F             NORM             NaN    NaN     NaN
# 79   mdb079              F             NORM             NaN    NaN     NaN
# 80   mdb080              F             CIRC        B  432.0  149.0    20.0
# 81   mdb081              G             ASYM        B  492.0  473.0   131.0
# 82   mdb082              G             NORM             NaN    NaN     NaN
# 83   mdb083              G             ASYM        B  544.0  194.0    38.0
# 84   mdb084              G             NORM             NaN    NaN     NaN
# 85   mdb085              G             NORM             NaN    NaN     NaN
# 86   mdb086              G             NORM             NaN    NaN     NaN
# 87   mdb087              F             NORM             NaN    NaN     NaN
# 88   mdb088              F             NORM             NaN    NaN     NaN
# 89   mdb089              G             NORM             NaN    NaN     NaN
# 90   mdb090              G             ASYM        M  510.0  547.0    49.0
# 91   mdb091              F             CIRC        B  680.0  494.0    20.0
# 92   mdb092              F             ASYM        M  423.0  662.0    43.0
# 93   mdb093              G             NORM             NaN    NaN     NaN
# 94   mdb094              G             NORM             NaN    NaN     NaN
# 95   mdb095              F             ASYM        M  466.0  517.0    29.0
# 96   mdb096              F             NORM             NaN    NaN     NaN
# 97   mdb097              F             ASYM        B  612.0  297.0    34.0
# 98   mdb098              F             NORM             NaN    NaN     NaN
# 99   mdb099              D             ASYM        B  714.0  340.0    23.0
# 100  mdb100              D             NORM             NaN    NaN     NaN
# 101  mdb101              D             NORM             NaN    NaN     NaN
# 102  mdb102              D             ASYM        M  415.0  460.0    38.0
# 103  mdb103              D             NORM             NaN    NaN     NaN
# 104  mdb104              D             ASYM        B  357.0  365.0    50.0
# 105  mdb105              D             ASYM        M  516.0  279.0    98.0
# 106  mdb106              D             NORM             NaN    NaN     NaN
# 107  mdb107              D             ASYM        B  600.0  621.0   111.0
# 108  mdb108              D             NORM             NaN    NaN     NaN
# 109  mdb109              D             NORM             NaN    NaN     NaN
# 110  mdb110              D             ASYM        M  190.0  427.0    51.0
# 111  mdb111              D             ASYM        M  505.0  575.0   107.0
# 112  mdb112              D             NORM             NaN    NaN     NaN
# 113  mdb113              G             NORM             NaN    NaN     NaN
# 114  mdb114              G             NORM             NaN    NaN     NaN
# 115  mdb115              G             ARCH        M  461.0  532.0   117.0
# 116  mdb116              G             NORM             NaN    NaN     NaN
# 117  mdb117              G             ARCH        M  480.0  576.0    84.0
# 118  mdb118              G             NORM             NaN    NaN     NaN
# 119  mdb119              G             NORM             NaN    NaN     NaN
# 120  mdb120              G             ARCH        M  423.0  262.0    79.0
# 121  mdb121              G             ARCH        B  492.0  434.0    87.0
# 122  mdb122              G             NORM             NaN    NaN     NaN
# 123  mdb123              G             NORM             NaN    NaN     NaN
# 124  mdb124              G             ARCH        M  366.0  620.0    33.0
# 125  mdb125              D             ARCH        M  700.0  552.0    60.0
# 126  mdb126              D             ARCH        B  191.0  549.0    23.0
# 127  mdb127              G             ARCH        B  523.0  551.0    48.0
# 128  mdb128              G             NORM             NaN    NaN     NaN
# 129  mdb129              D             NORM             NaN    NaN     NaN
# 130  mdb130              D             ARCH        M  220.0  552.0    28.0
# 131  mdb131              F             NORM             NaN    NaN     NaN
# 132  mdb132              F             CIRC        B  252.0  788.0    52.0
# 133  mdb132              F             CIRC        B  335.0  766.0    18.0
# 134  mdb133              F             NORM             NaN    NaN     NaN
# 135  mdb134              F             MISC        M  469.0  728.0    49.0
# 136  mdb135              F             NORM             NaN    NaN     NaN
# 137  mdb136              F             NORM             NaN    NaN     NaN
# 138  mdb137              D             NORM             NaN    NaN     NaN
# 139  mdb138              D             NORM             NaN    NaN     NaN
# 140  mdb139              F             NORM             NaN    NaN     NaN
# 141  mdb140              F             NORM             NaN    NaN     NaN
# 142  mdb141              F             CIRC        M  470.0  759.0    29.0
# 143  mdb142              F             CIRC        B  347.0  636.0    26.0
# 144  mdb143              F             NORM             NaN    NaN     NaN
# 145  mdb144              F             MISC        B  233.0  994.0    29.0
# 146  mdb144              F             MISC        M  313.0  540.0    27.0
# 147  mdb145              D             SPIC        B  669.0  543.0    49.0
# 148  mdb146              D             NORM             NaN    NaN     NaN
# 149  mdb147              F             NORM             NaN    NaN     NaN
# 150  mdb148              F             SPIC        M  326.0  607.0   174.0
# 151  mdb149              F             NORM             NaN    NaN     NaN
# 152  mdb150              F             ARCH        B  351.0  661.0    62.0
# 153  mdb151              F             NORM             NaN    NaN     NaN
# 154  mdb152              F             ARCH        B  675.0  486.0    48.0
# 155  mdb153              F             NORM             NaN    NaN     NaN
# 156  mdb154              F             NORM             NaN    NaN     NaN
# 157  mdb155              F             ARCH        M  448.0  480.0    95.0
# 158  mdb156              F             NORM             NaN    NaN     NaN
# 159  mdb157              F             NORM             NaN    NaN     NaN
# 160  mdb158              F             ARCH        M  540.0  565.0    88.0
# 161  mdb159              F             NORM             NaN    NaN     NaN
# 162  mdb160              F             ARCH        B  536.0  519.0    61.0
# 163  mdb161              D             NORM             NaN    NaN     NaN
# 164  mdb162              D             NORM             NaN    NaN     NaN
# 165  mdb163              D             ARCH        B  391.0  365.0    50.0
# 166  mdb164              D             NORM             NaN    NaN     NaN
# 167  mdb165              D             ARCH        B  537.0  490.0    42.0
# 168  mdb166              D             NORM             NaN    NaN     NaN
# 169  mdb167              F             ARCH        B  574.0  657.0    35.0
# 170  mdb168              F             NORM             NaN    NaN     NaN
# 171  mdb169              D             NORM             NaN    NaN     NaN
# 172  mdb170              D             ARCH        M  489.0  480.0    82.0
# 173  mdb171              D             ARCH        M  462.0  627.0    62.0
# 174  mdb172              D             NORM             NaN    NaN     NaN
# 175  mdb173              F             NORM             NaN    NaN     NaN
# 176  mdb174              F             NORM             NaN    NaN     NaN
# 177  mdb175              G             SPIC        B  592.0  670.0    33.0
# 178  mdb176              G             NORM             NaN    NaN     NaN
# 179  mdb177              G             NORM             NaN    NaN     NaN
# 180  mdb178              G             SPIC        M  492.0  600.0    70.0
# 181  mdb179              D             SPIC        M  600.0  514.0    67.0
# 182  mdb180              D             NORM             NaN    NaN     NaN
# 183  mdb181              G             SPIC        M  519.0  362.0    54.0
# 184  mdb182              G             NORM             NaN    NaN     NaN
# 185  mdb183              F             NORM             NaN    NaN     NaN
# 186  mdb184              F             SPIC        M  352.0  624.0   114.0
# 187  mdb185              G             NORM             NaN    NaN     NaN
# 188  mdb186              G             SPIC        M  403.0  524.0    47.0
# 189  mdb187              G             NORM             NaN    NaN     NaN
# 190  mdb188              G             SPIC        B  406.0  617.0    61.0
# 191  mdb189              G             NORM             NaN    NaN     NaN
# 192  mdb190              G             SPIC        B  512.0  621.0    31.0
# 193  mdb191              G             SPIC        B  594.0  516.0    41.0
# 194  mdb192              G             NORM             NaN    NaN     NaN
# 195  mdb193              D             SPIC        B  399.0  563.0   132.0
# 196  mdb194              D             NORM             NaN    NaN     NaN
# 197  mdb195              F             SPIC        B  725.0  129.0    26.0
# 198  mdb196              F             NORM             NaN    NaN     NaN
# 199  mdb197              D             NORM             NaN    NaN     NaN
# 200  mdb198              D             SPIC        B  568.0  612.0    93.0
# 201  mdb199              D             SPIC        B  641.0  177.0    31.0
# 202  mdb200              D             NORM             NaN    NaN     NaN
# 203  mdb201              D             NORM             NaN    NaN     NaN
# 204  mdb202              D             SPIC        M  557.0  772.0    37.0
# 205  mdb203              F             NORM             NaN    NaN     NaN
# 206  mdb204              F             SPIC        B  336.0  399.0    21.0
# 207  mdb205              F             NORM             NaN    NaN     NaN
# 208  mdb206              F             SPIC        M  368.0  200.0    17.0
# 209  mdb207              D             SPIC        B  571.0  564.0    19.0
# 210  mdb208              D             NORM             NaN    NaN     NaN
# 211  mdb209              G             CALC        M  647.0  503.0    87.0
# 212  mdb210              G             NORM             NaN    NaN     NaN
# 213  mdb211              G             CALC        M  680.0  327.0    13.0
# 214  mdb212              G             CALC        B  687.0  882.0     3.0
# 215  mdb213              G             CALC        M  547.0  520.0    45.0
# 216  mdb214              G             CALC        B  582.0  916.0    11.0
# 217  mdb215              D             NORM             NaN    NaN     NaN
# 218  mdb217              G             NORM             NaN    NaN     NaN
# 219  mdb218              G             CALC        B  519.0  629.0     8.0
# 220  mdb219              G             CALC        B  546.0  756.0    29.0
# 221  mdb220              G             NORM             NaN    NaN     NaN
# 222  mdb221              D             NORM             NaN    NaN     NaN
# 223  mdb222              D             CALC        B  398.0  427.0    17.0
# 224  mdb223              D             CALC        B  523.0  482.0    29.0
# 225  mdb223              D             CALC        B  591.0  529.0     6.0
# 226  mdb224              D             NORM             NaN    NaN     NaN
# 227  mdb225              D             NORM             NaN    NaN     NaN
# 228  mdb226              D             CALC        B  287.0  610.0     7.0
# 229  mdb226              D             CALC        B  329.0  550.0    25.0
# 230  mdb226              D             CALC        B  531.0  721.0     8.0
# 231  mdb227              G             CALC        B  504.0  467.0     9.0
# 232  mdb228              G             NORM             NaN    NaN     NaN
# 233  mdb229              F             NORM             NaN    NaN     NaN
# 234  mdb230              F             NORM             NaN    NaN     NaN
# 235  mdb231              F             CALC        M  603.0  538.0    44.0
# 236  mdb232              F             NORM             NaN    NaN     NaN
# 237  mdb234              G             NORM             NaN    NaN     NaN
# 238  mdb235              D             NORM             NaN    NaN     NaN
# 239  mdb236              D             CALC        B  276.0  824.0    14.0
# 240  mdb237              F             NORM             NaN    NaN     NaN
# 241  mdb238              F             CALC        M  522.0  553.0    17.0
# 242  mdb239              D             CALC        M  645.0  755.0    40.0
# 243  mdb239              D             CALC        M  567.0  808.0    25.0
# 244  mdb240              D             CALC        B  643.0  614.0    23.0
# 245  mdb241              D             CALC        M  453.0  678.0    38.0
# 246  mdb242              D             NORM             NaN    NaN     NaN
# 247  mdb243              D             NORM             NaN    NaN     NaN
# 248  mdb244              D             CIRC        B  466.0  567.0    52.0
# 249  mdb246              F             NORM             NaN    NaN     NaN
# 250  mdb247              F             NORM             NaN    NaN     NaN
# 251  mdb248              F             CALC        B  378.0  601.0    10.0
# 252  mdb249              D             CALC        M  544.0  508.0    48.0
# 253  mdb249              D             CALC        M  575.0  639.0    64.0
# 254  mdb250              D             NORM             NaN    NaN     NaN
# 255  mdb251              F             NORM             NaN    NaN     NaN
# 256  mdb252              F             CALC        B  439.0  367.0    23.0
# 257  mdb253              D             CALC        M  733.0  564.0    28.0
# 258  mdb254              D             NORM             NaN    NaN     NaN
# 259  mdb255              F             NORM             NaN    NaN     NaN
# 260  mdb256              F             CALC        M  400.0  484.0    37.0
# 261  mdb257              D             NORM             NaN    NaN     NaN
# 262  mdb258              D             NORM             NaN    NaN     NaN
# 263  mdb259              D             NORM             NaN    NaN     NaN
# 264  mdb260              D             NORM             NaN    NaN     NaN
# 265  mdb261              D             NORM             NaN    NaN     NaN
# 266  mdb262              D             NORM             NaN    NaN     NaN
# 267  mdb263              G             NORM             NaN    NaN     NaN
# 268  mdb264              G             MISC        M  596.0  431.0    36.0
# 269  mdb265              G             MISC        M  593.0  498.0    60.0
# 270  mdb266              G             NORM             NaN    NaN     NaN
# 271  mdb267              F             MISC        M  793.0  481.0    56.0
# 272  mdb268              F             NORM             NaN    NaN     NaN
# 273  mdb269              G             NORM             NaN    NaN     NaN
# 274  mdb270              G             CIRC        M  356.0  945.0    72.0
# 275  mdb271              F             MISC        M  784.0  270.0    68.0
# 276  mdb272              F             NORM             NaN    NaN     NaN
# 277  mdb273              F             NORM             NaN    NaN     NaN
# 278  mdb274              F             MISC        M  127.0  505.0   123.0
# 279  mdb275              G             NORM             NaN    NaN     NaN
# 280  mdb276              G             NORM             NaN    NaN     NaN
# 281  mdb277              G             NORM             NaN    NaN     NaN
# 282  mdb278              G             NORM             NaN    NaN     NaN
# 283  mdb279              G             NORM             NaN    NaN     NaN
# 284  mdb280              G             NORM             NaN    NaN     NaN
# 285  mdb281              D             NORM             NaN    NaN     NaN
# 286  mdb282              D             NORM             NaN    NaN     NaN
# 287  mdb283              D             NORM             NaN    NaN     NaN
# 288  mdb284              D             NORM             NaN    NaN     NaN
# 289  mdb285              D             NORM             NaN    NaN     NaN
# 290  mdb286              D             NORM             NaN    NaN     NaN
# 291  mdb287              D             NORM             NaN    NaN     NaN
# 292  mdb288              D             NORM             NaN    NaN     NaN
# 293  mdb289              D             NORM             NaN    NaN     NaN
# 294  mdb290              D             CIRC        B  337.0  353.0    45.0
# 295  mdb291              G             NORM             NaN    NaN     NaN
# 296  mdb292              G             NORM             NaN    NaN     NaN
# 297  mdb293              F             NORM             NaN    NaN     NaN
# 298  mdb294              F             NORM             NaN    NaN     NaN
# 299  mdb295              D             NORM             NaN    NaN     NaN
# 300  mdb296              D             NORM             NaN    NaN     NaN
# 301  mdb297              F             NORM             NaN    NaN     NaN
# 302  mdb298              F             NORM             NaN    NaN     NaN
# 303  mdb299              F             NORM             NaN    NaN     NaN
# 304  mdb300              F             NORM             NaN    NaN     NaN
# 305  mdb301              F             NORM             NaN    NaN     NaN
# 306  mdb302              F             NORM             NaN    NaN     NaN
# 307  mdb303              F             NORM             NaN    NaN     NaN
# 308  mdb304              F             NORM             NaN    NaN     NaN
# 309  mdb305              F             NORM             NaN    NaN     NaN
# 310  mdb306              F             NORM             NaN    NaN     NaN
# 311  mdb307              F             NORM             NaN    NaN     NaN
# 312  mdb308              F             NORM             NaN    NaN     NaN
# 313  mdb309              F             NORM             NaN    NaN     NaN
# 314  mdb310              F             NORM             NaN    NaN     NaN
# 315  mdb311              F             NORM             NaN    NaN     NaN
# 316  mdb312              F             MISC        B  240.0  263.0    20.0
# 317  mdb313              F             NORM             NaN    NaN     NaN
# 318  mdb314              F             MISC        B  518.0  191.0    39.0
# 319  mdb315              D             CIRC        B  516.0  447.0    93.0
# 320  mdb316              D             NORM             NaN    NaN     NaN
# 321  mdb317              D             NORM             NaN    NaN     NaN
# 322  mdb318              D             NORM             NaN    NaN     NaN
# 323  mdb319              D             NORM             NaN    NaN     NaN
# 324  mdb320              D             NORM             NaN    NaN     NaN
# 325  mdb321              D             NORM             NaN    NaN     NaN
# 326  mdb322              D             NORM             NaN    NaN     NaN

# %%
df_info_filtered.to_csv("filtered_info.csv", index=False)

# %%
df_info_filtered.to_csv("/content/drive/MyDrive/MIAS_third_try/filtered_info.csv", index=False)
